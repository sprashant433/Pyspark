# %%
# PySpark Setup - Run this cell first
# For Google Colab:
import sys
IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
    # !pip install pyspark -q
    # !pip install findspark -q
    import findspark
    findspark.init()

# %%
# Import SparkSession
from pyspark.sql import SparkSession

# Create SparkSession
spark = SparkSession.builder \
        .master("local[*]") \
        .appName("example1") \
        .getOrCreate()

# %%
def my_fun(fun):
    print('I am my_fun: start')
    fun()
    print('I am my_fun: executed')

# %%
@my_fun
def please_use():
    print('I am please use')
# Out:
# I am my_fun: start
# I am please use
# I am my_fun: executed
